# %%
import pandas as pd
import numpy as np

# %%
test_data = pd.read_csv("titanic/test.csv")

train_data = pd.read_csv("titanic/train.csv")

# %%
test_data.shape
# Out:
# (418, 11)

# %%
test_data.sample(5)
# Out:
#      PassengerId  Pclass                       Name     Sex    Age  SibSp  \
# 120         1012       2       Watt, Miss. Bertha J  female  12.00      0
# 307         1199       3  Aks, Master. Philip Frank    male   0.83      0
# 357         1249       3        Lockyer, Mr. Edward    male    NaN      0
# 40           932       3           Karun, Mr. Franz    male  39.00      0
# 366         1258       3          Caram, Mr. Joseph    male    NaN      1
#
#      Parch      Ticket     Fare Cabin Embarked
# 120      0  C.A. 33595  15.7500   NaN        S
# 307      1      392091   9.3500   NaN        S
# 357      0        1222   7.8792   NaN        S
# 40       1      349256  13.4167   NaN        C
# 366      0        2689  14.4583   NaN        C

# %%
test_data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
missing_values_count = test_data.isnull().sum()

# %%
print(missing_values_count)
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
total_cells = np.prod(test_data.shape)

# %%
total_missing = missing_values_count.sum()

# %%
missing_value_perc = total_missing / total_cells * 100

# %%
print(missing_value_perc)
# Out:
# 9.00391474554154

# %%
test_data.fillna({"Age": test_data["Age"].median()}, inplace = True)
test_data.fillna({"Cabin": "Lower Class"}, inplace = True)
test_data.fillna({"Fare": test_data["Fare"].median()}, inplace = True)

test_data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  418.000000  418.000000  418.000000  418.000000
# mean   1100.500000    2.265550   29.599282    0.447368    0.392344   35.576535
# std     120.810458    0.841838   12.703770    0.896760    0.981429   55.850103
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   23.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   35.750000    1.000000    0.000000   31.471875
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
test_data.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
test_data.sample(5)
# Out:
#      PassengerId  Pclass                       Name     Sex   Age  SibSp  \
# 155         1047       3       Duquemin, Mr. Joseph    male  24.0      0
# 120         1012       2       Watt, Miss. Bertha J  female  12.0      0
# 357         1249       3        Lockyer, Mr. Edward    male  27.0      0
# 252         1144       1   Clark, Mr. Walter Miller    male  27.0      1
# 58           950       3  Davison, Mr. Thomas Henry    male  27.0      1
#
#      Parch         Ticket      Fare        Cabin Embarked
# 155      0  S.O./P.P. 752    7.5500  Lower Class        S
# 120      0     C.A. 33595   15.7500  Lower Class        S
# 357      0           1222    7.8792  Lower Class        S
# 252      0          13508  136.7792          C89        C
# 58       0         386525   16.1000  Lower Class        S
